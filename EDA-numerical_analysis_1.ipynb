# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
path=r"C:\Users\devis\OneDrive\Documents\data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
#visa_df.iloc[:,'prevailing_wage']
#visa_df.loc[:,[8]]
#visa_df['prevailing_wage']
#visa_df[['prevailing_wage']]

# %%
visa_df[['prevailing_wage']]
# Out:
#        prevailing_wage
# 0             592.2029
# 1           83425.6500
# 2          122996.8600
# 3           83434.0300
# 4          149907.3900
# ...                ...
# 25475       77092.5700
# 25476      279174.7900
# 25477      146298.8500
# 25478       86154.7700
# 25479       70876.9100
#
# [25480 rows x 1 columns]

# %% [markdown]
# - len
# - min
# - max
# - average(mean)
# - standard deviation
# - median
# - 25p
# - 50p
# - 75p

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %%
min(visa_df['prevailing_wage'])
# Out:
# 2.1367

# %%
max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
count=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
print("the number of wage samples are:",count)
print("the minimum wage is:",min_wage)
print("the maximu wage is:",max_wage)
# Out:
# the number of wage samples are: 25480
# the minimum wage is: 2.1367
# the maximu wage is: 319210.27

# %%
visa_df[['prevailing_wage']].mean()
# Out:
# prevailing_wage    74455.814592
# dtype: float64

# %%
visa_df[['prevailing_wage']].median()
# Out:
# prevailing_wage    70308.21
# dtype: float64

# %%
mean_wage=round(visa_df['prevailing_wage'].mean(),2)
median_wage=round(visa_df['prevailing_wage'].median(),2)
print("The average wage is:",mean_wage)
print("The median wage is:",median_wage)
# Out:
# The average wage is: 74455.81
# The median wage is: 70308.21

# %% [markdown]
# - Mode is not a suitable metric for numerical analysis
# - Different observations can have same values

# %% [markdown]
# # using numpy

# %%
np.mean(visa_df['prevailing_wage'])
# Out:
# 74455.81459209183

# %%
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %%
std_wage=round(visa_df['prevailing_wage'].std(),2)
std_wage
# Out:
# 52815.94

# %%
count_wage=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
mean_wage=round(visa_df['prevailing_wage'].mean(),2)
median_wage=round(visa_df['prevailing_wage'].median(),2)
std_wage=round(visa_df['prevailing_wage'].std(),2)

# %%
# Step-1: Create a empty list , keep all the values in a list
# Step-2: create a index list= ['Count','min','max']
# Step-3: create a cols list = ['pwage']
values=[count_wage,min_wage,max_wage,
mean_wage,median_wage,std_wage]
index=['count','min','max','mean','median','std']
cols=['prevailing_wage']
wage_df=pd.DataFrame(values,index=index,columns=cols)
wage_df
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       70308.2100
# std          52815.9400

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# # 25p-50p-75p
# # percentile
# - in numpy we have a percentile
# - the method is np.percentile()
# - it takes 2 arguments
#     - a:array means data
#     - q:value which percentile data we want,the value we need to provide
#     - if we want 25p value then q=25
# # quantile
# - in numpy we have a percentile
# - the method is np.quantile()
# - it takes 2 arguments
#     - a:array means data
#     - q:value which percentile data we want,the value we need to provide
#     - if we want 25p value then q=0.25

# %%
#if we want 25p value then q=0.25
#if we want 50p value then q=0.50



np.quantile(visa_df['prevailing_wage'],0.25)
# Out:
# 34015.479999999996

# %%
np.percentile(visa_df['prevailing_wage'],30)
# Out:
# 42032.848999999995

# %%
wage_25p=round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p=round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p=round(np.percentile(visa_df['prevailing_wage'],75),2)
print("25p value is:",wage_25p)
print("50p value is:",wage_50p)
print("75p value is:",wage_75p)
# Out:
# 25p value is: 34015.48
# 50p value is: 70308.21
# 75p value is: 107735.51

# %%
count_wage=len(visa_df['prevailing_wage'])
min_wage=min(visa_df['prevailing_wage'])
max_wage=max(visa_df['prevailing_wage'])
mean_wage=round(visa_df['prevailing_wage'].mean(),2)
median_wage=round(visa_df['prevailing_wage'].median(),2)
std_wage=round(visa_df['prevailing_wage'].std(),2)
wage_25p=round(np.percentile(visa_df['prevailing_wage'],25),2)
wage_50p=round(np.percentile(visa_df['prevailing_wage'],50),2)
wage_75p=round(np.percentile(visa_df['prevailing_wage'],75),2)
values=[count_wage,min_wage,max_wage,
mean_wage,median_wage,std_wage,wage_25p,wage_50p,wage_75p]
index=['count','min','max','mean','median','std','25p','50p','75p']
cols=['prevailing_wage']
wage_df=pd.DataFrame(values,index=index,columns=cols)
wage_df
# Out:
#         prevailing_wage
# count        25480.0000
# min              2.1367
# max         319210.2700
# mean         74455.8100
# median       70308.2100
# std          52815.9400
# 25p          34015.4800
# 50p          70308.2100
# 75p         107735.5100

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\devis\OneDrive\Documents\data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
df1=pd.DataFrame()
for i in num_columns:
    Count=len(visa_df[i])
    Min=min(visa_df[i])
    Max=max(visa_df[i])
    Mean=round(visa_df[i].mean(),2)
    Median=round(visa_df[i].median(),2)
    Std=round(visa_df[i].std(),2)
    p_25=round(np.percentile(visa_df[i],25),2)
    p_50=round(np.percentile(visa_df[i],50),2)
    p_75=round(np.percentile(visa_df[i],75),2)
    values=[Count,Min,Max,
    Mean,Median,Std,p_25,p_50,p_75]
    index=['count','min','max','mean','median','std','25p','50p','75p']
    cols=[i]
    df2=pd.DataFrame(values,index=index,columns=cols)
    df1=pd.concat([df1,df2],axis=1)
df1
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00       25480.0000
# min              -26.00      1800.00           2.1367
# max           602069.00      2016.00      319210.2700
# mean            5667.04      1979.41       74455.8100
# median          2109.00      1997.00       70308.2100
# std            22877.93        42.37       52815.9400
# 25p             1022.00      1976.00       34015.4800
# 50p             2109.00      1997.00       70308.2100
# 75p             3504.00      2005.00      107735.5100

# %% [markdown]
# # percentiles
# # 25p:
# - assume that 25p value=x
# - 25percentage of data less than x
# - for example prevailing_wage 25p value is:34015.47
# - means 25 percentage of people having  salary less than 34015.47
# - total members:25480
# - which means 25percentage: 25*25480/100=6370
# - means 6370 people having salary less than 34015

# %%
np.percentile(visa_df['prevailing_wage'],25)
# Out:
# 34015.479999999996

# %%
# step-1:read the prevailing_wage data
# tep-2:provide the condition which means
# prevailing_wage<percentile value

# %%
wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],25)
wage_data<p_25
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],25)
con=wage_data<p_25
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# 16        EZYV17         Europe              Master's                  Y
# 17        EZYV18           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25461  EZYV25462           Asia              Master's                  Y
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
len(visa_df['prevailing_wage'])
# Out:
# 25480

# %% [markdown]
# # 50p:
# - assume that 50p value=x
# - 50percentage of data less than x
# - for example prevailing_wage 50p value is:70308
# - means 25 percentage of people having salary less than 70308
# - total members:25480
# - which means 25percentage: 25*25480/100=12740
# - means 127490 people having salary less than 70308

# %%
np.percentile(visa_df['prevailing_wage'],50)
# Out:
# 70308.20999999999

# %%
50*25480/100
# Out:
# 12740.0

# %%
wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],50)
wage_data<p_50
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 25475    False
# 25476    False
# 25477    False
# 25478    False
# 25479    False
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
75*25480/100
# Out:
# 19110.0

# %%
wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],50)
con=wage_data<p_50
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 9         EZYV10         Europe             Doctorate                  Y
# 12        EZYV13           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# - 75p:
# - assume that 75p value=x
# - 50percentage of data less than x
# - for example prevailing_wage 75p value is:107735
# - means 75 percentage of people having salary less than 107735
# - total members:25480
# - which means 25percentage: 75*25480/100=19110
# - means 19110 people having salary less than 107735

# %%
np.percentile(visa_df['prevailing_wage'],75)
# Out:
# 107735.51250000001

# %%
wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],75)
wage_data<p_75
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478     True
# 25479     True
# Name: prevailing_wage, Length: 25480, dtype: bool

# %%
wage_data=visa_df['prevailing_wage']
p_25=np.percentile(visa_df['prevailing_wage'],75)
con=wage_data<p_75
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# # emperical rule

# %% [markdown]
# - 68-95-99.7
# - 68% data will cover between μ_1-1σ and μ_1+1σ
# - 95% data will cover between μ_1-2σ and μ_1+2σ
# - 99.7% data will cover between μ_1-3σ and

# %%
# step-1:calculate the mean of prevailing wage
#step-2:cal std deviation of prevailing wage
#step-3:lb=mean-1*std
#step-4:up-mean+1*std
#step-5:con1=data<ub
#step-6:con3=dasta>lb
#step-7:coon3=con1 and con2
#step-8:data[con3]
#step-9:compare with 68% 25480

# %%
mu=visa_df[['prevailing_wage']].mean()
mu
# Out:
# prevailing_wage    74455.814592
# dtype: float64

# %%
sigma=visa_df[['prevailing_wage']].std()
sigma
# Out:
# prevailing_wage    52815.942327
# dtype: float64

# %%
# for 68%
mu=visa_df['prevailing_wage'].mean()
sigma=visa_df['prevailing_wage'].std()
lb=mu-1*sigma
ub=mu+1*sigma
con1=visa_df['prevailing_wage'] < ub
con2=visa_df['prevailing_wage'] > lb
con3=con1&con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
total_count=len(visa_df['prevailing_wage'])
per_68=total_count*68
count_1=len(visa_df[con3])
count_1
# Out:
# 17171

# %%
#for 95%
mu1=visa_df['prevailing_wage'].mean()
sigma1=visa_df['prevailing_wage'].std()
lb=mu1-2*sigma1
ub=mu1+2*sigma1
con11=visa_df['prevailing_wage'] < ub
con22=visa_df['prevailing_wage'] > lb
con33=con11&con22
print(len(visa_df[con33]))
print(95*len(visa_df)/100)
# Out:
# 24582
# 24206.0

# %%
#99.7%
mu2=visa_df['prevailing_wage'].mean()
sigma2=visa_df['prevailing_wage'].std()
lb=mu2-3*sigma2
ub=mu2+3*sigma2
con12=visa_df['prevailing_wage'] < ub
con21=visa_df['prevailing_wage'] > lb
con31=con12&con21
visa_df[con31]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
mu2=visa_df['prevailing_wage'].mean()
sigma2=visa_df['prevailing_wage'].std()
lb=mu2-3*sigma2
ub=mu2+3*sigma2
con12=visa_df['prevailing_wage'] < ub
con21=visa_df['prevailing_wage'] > lb
con31=con12&con21
print(len(visa_df[con31]))
print(99.7*len(visa_df)/100)
# Out:
# 25186
# 25403.56

# %%
len(visa_df[con31])
# Out:
# 25186

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\devis\OneDrive\Documents\data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # describe function

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# # histogram

# %% [markdown]
# - by aplying empirical rule we observed slide deviation in the count of data
# - also mean median comparision
# - mean is slightly deviated from median
# - this gives an indication tot the data doesnt follows normal distribution
# - to understand more clearly will visualize the data
# - it is numerical data,so the plot name is 'histogram'
# - histogram is a graph b/w class intervals and class interval frequency
# - the plot is available in matplotlib
# - the method name is hist

# %%
# step-1:read the prevailing wage
# step-2:plt.hist()

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data,bins=10)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data,bins=20)
# Out:
# (array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#          882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#           10.,   11.]),
#  array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#         6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#         1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#         1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#         2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#         3.19210270e+05]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# - histogram will return 3 values
#    - 1.interval count array
#         - we have 20 intervals ,so we have 20 interval counts
#    -  2.bins
#        - bins means no of intervals
#        - we have 20 intervals so we need 20 values
#    - will display how many intervals are  available
# - for example in the bins array the first two forms one interval
# - 2.136 to 15962.543 the count is 3863
# - 3863 obswervations are available between 2.136 to 15962.543
# - similarly 2175 observations b/w (15962.5434,31922.95)

# %%
wage_data=visa_df['prevailing_wage']
count,bins,x=plt.hist(wage_data,bins=20)
print(len(count))
print(len(bins))
print(x)
# Out:
# 20
# 21
# <BarContainer object of 20 artists>

# %%
lb=2.13670000e+00
ub=1.59625434e+04
con12=visa_df['prevailing_wage'] <= ub
con21=visa_df['prevailing_wage'] >= lb
con31=con12&con21
print(len(visa_df[con31]))
# Out:
# 3863

# %%
lb=1.59625434e+04
ub=3.19229500e+04
con12=visa_df['prevailing_wage'] <= ub
con21=visa_df['prevailing_wage'] >= lb
con31=con12&con21
print(len(visa_df[con31]))
# Out:
# 2175

# %%
lb=3.19229500e+04
ub= 4.78833567e+04
con12=visa_df['prevailing_wage'] <= ub
con21=visa_df['prevailing_wage'] >= lb
con31=con12&con21
print(len(visa_df[con31]))
# Out:
# 2676

# %%
count
# Out:
# array([3863., 2175., 2676., 2828., 2889., 2792., 2485., 2066., 1452.,
#         882.,  408.,  216.,  206.,  167.,  129.,  111.,   66.,   48.,
#          10.,   11.])

# %%
bins
# Out:
# array([2.13670000e+00, 1.59625434e+04, 3.19229500e+04, 4.78833567e+04,
#        6.38437634e+04, 7.98041700e+04, 9.57645767e+04, 1.11724983e+05,
#        1.27685390e+05, 1.43645797e+05, 1.59606203e+05, 1.75566610e+05,
#        1.91527017e+05, 2.07487423e+05, 2.23447830e+05, 2.39408237e+05,
#        2.55368643e+05, 2.71329050e+05, 2.87289457e+05, 3.03249863e+05,
#        3.19210270e+05])

# %%
import pandas as pd
df=pd.DataFrame(list(zip(bins,count)),columns=['bins','count'])
df
# Out:
#              bins   count
# 0        2.136700  3863.0
# 1    15962.543365  2175.0
# 2    31922.950030  2676.0
# 3    47883.356695  2828.0
# 4    63843.763360  2889.0
# 5    79804.170025  2792.0
# 6    95764.576690  2485.0
# 7   111724.983355  2066.0
# 8   127685.390020  1452.0
# 9   143645.796685   882.0
# 10  159606.203350   408.0
# 11  175566.610015   216.0
# 12  191527.016680   206.0
# 13  207487.423345   167.0
# 14  223447.830010   129.0
# 15  239408.236675   111.0
# 16  255368.643340    66.0
# 17  271329.050005    48.0
# 18  287289.456670    10.0
# 19  303249.863335    11.0

# %%
import pandas as pd
df=pd.DataFrame(list(zip(bins[:-1],count)),columns=['bins','count'])
df
# Out:
#              bins   count
# 0        2.136700  3863.0
# 1    15962.543365  2175.0
# 2    31922.950030  2676.0
# 3    47883.356695  2828.0
# 4    63843.763360  2889.0
# 5    79804.170025  2792.0
# 6    95764.576690  2485.0
# 7   111724.983355  2066.0
# 8   127685.390020  1452.0
# 9   143645.796685   882.0
# 10  159606.203350   408.0
# 11  175566.610015   216.0
# 12  191527.016680   206.0
# 13  207487.423345   167.0
# 14  223447.830010   129.0
# 15  239408.236675   111.0
# 16  255368.643340    66.0
# 17  271329.050005    48.0
# 18  287289.456670    10.0
# 19  303249.863335    11.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\devis\OneDrive\Documents\data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# draw the histogram using seaborn

# %% [markdown]
# # boxplot
# - box plot is used to identify the outliers
# - outlier is an observation having huge positive value or huge negative value
# - Q1=25P,Q2=50P,Q3=75P
# - IQR=inter quartile range=Q3-Q1
# - Q3+1.5*IQR and Q1-1.5*IQR

# %%
  Q1-1.5IQR            Q1   median  Q3    Q3+1.5IQR
                       |-----:-----|
       o      |--------|     :     |--------|    o  o
                       |-----:-----|
     flier             <----------->            fliers
                            IQR

# %%
wage_data=visa_df[['prevailing_wage']]
plt.boxplot(wage_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ee36cca3d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1ee36ccbb50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1ee36cc98d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ee36cd5250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ee36cd5d90>],
#  'means': []}

# %%
wage_data=visa_df[['prevailing_wage']]
plt.boxplot(wage_data,vert=False)
plt.title('boxplot')
plt.xlabel('wages')
plt.show()

# %%
wage_data=visa_df[['prevailing_wage']]
sns.boxplot(wage_data)
plt.title('boxplot')
plt.xlabel('wages')
plt.show()

# %%
# plot the histogram plot and boxplot side by side

# %%
wage_data=visa_df[['prevailing_wage']]
sns.boxplot(wage_data,orient='h')
plt.title('boxplot')
plt.xlabel('wages')
plt.show()

# %%
wage_data=visa_df[['prevailing_wage']]
plt.figure(figsize=(14,3))
plt.suptitle('comparision of histogram with boxplot')
plt.subplot(1,2,1)
plt.hist(wage_data,bins=20)
plt.xlabel('histogram')
plt.subplot(1,2,2)
plt.boxplot(wage_data,vert=False)
plt.xlabel('boxplot')
plt.show()

# %%
wage_data=visa_df[['prevailing_wage']]
plt.figure(figsize=(14,3))
plt.suptitle('comparision of histogram with boxplot')
plt.subplot(1,2,1).hist(wage_data,bins=20)
plt.xlabel('histogram')
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.xlabel('boxplot')
plt.show()

# %% [markdown]
# # finding the outliers

# %% [markdown]
# - we already know tat outliers available less than Q1-1.5*IQR and Q3+1.5*IQR
# - step-1:
#      - calculate Q1=25p
#     - calculate Q2=50p
#     - calculate Q3=75p
# - step-2:calculate IQR=Q3-Q1
# - step-3:
#        - calculate lb=Q1-1.5*IQR
#       - CAalculate ub=Q3+1.5*IQR
# - step-4:
#    - con1=wage data<lb
#    - con2=wate data>ub
#    - con3=con1|con2
# - step-5:data[con3]

# %%
#series type outliers
wage_data=visa_df['prevailing_wage']
Q1=np.percentile(wage_data,25)
Q2=np.percentile(wage_data,50)
Q3=np.percentile(wage_data,75)
IQR=Q3-Q1
lb=Q1-1.5*IQR
ub=Q3+1.5*IQR
con1=wage_data < lb
con2=wage_data > ub
con3=con1|con2
outlier_count=wage_data[con3]
outlier_count
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %%
#dataframe type outliers
Q1=np.percentile(visa_df['prevailing_wage'],25)
Q2=np.percentile(visa_df['prevailing_wage'],50)
Q3=np.percentile(visa_df['prevailing_wage'],75)
IQR=Q3-Q1
lb=Q1-1.5*IQR
ub=Q3+1.5*IQR
con1=visa_df['prevailing_wage'] < lb
con2=visa_df['prevailing_wage'] > ub
con3=con1|con2
outlier_count=visa_df[con3]
outlier_count
# bitwise operators used to compare bits data==0 and 1===true false
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 14        EZYV15           Asia              Master's                  Y
# 34        EZYV35           Asia              Master's                  N
# 130      EZYV131  South America           High School                  N
# 216      EZYV217           Asia              Master's                  Y
# 221      EZYV222  North America             Doctorate                  Y
# ...          ...            ...                   ...                ...
# 25191  EZYV25192           Asia              Master's                  N
# 25195  EZYV25196  North America              Master's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
#series type non outlier
wage_data=visa_df['prevailing_wage']
Q1=np.percentile(wage_data,25)
Q2=np.percentile(wage_data,50)
Q3=np.percentile(wage_data,75)
IQR=Q3-Q1
lb=Q1-1.5*IQR
ub=Q3+1.5*IQR
con1=wage_data >lb
con2=wage_data <ub
con3=con1&con2
non_outlier_count=wage_data[con3]
non_outlier_count
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25474     51104.7800
# 25475     77092.5700
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25053, dtype: float64

# %%
#dataframe type non outlier
Q1=np.percentile(visa_df['prevailing_wage'],25)
Q2=np.percentile(visa_df['prevailing_wage'],50)
Q3=np.percentile(visa_df['prevailing_wage'],75)
IQR=Q3-Q1
lb=Q1-1.5*IQR
ub=Q3+1.5*IQR
con1=visa_df['prevailing_wage'] > lb
con2=visa_df['prevailing_wage'] < ub
con3=con1&con2
non_outlier_count=visa_df[con3]
non_outlier_count
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - we are 2 dataframes
# - 1.visa_df:total data 25480
# - 2.non_outliers_df=after removing outliers 25053

# %%
wage_data=non_outlier_count['prevailing_wage']
plt.figure(figsize=(14,3))
plt.suptitle('comparision of histogram with boxplot')
plt.subplot(1,2,1).hist(wage_data,bins=20)
plt.xlabel('histogram')
plt.subplot(1,2,2).boxplot(wage_data,vert=False)
plt.xlabel('boxplot')
plt.show()

# %%
wage_data=visa_df[['prevailing_wage']]
plt.figure(figsize=(14,8))
plt.suptitle('comparision of histogram with boxplot')
plt.subplot(2,2,1).hist(wage_data,bins=20)
plt.xlabel('histogram')
plt.subplot(2,2,2).boxplot(wage_data,vert=False)
plt.xlabel('boxplot')
wage_data1=non_outlier_count['prevailing_wage']
plt.subplot(2,2,3).hist(wage_data1,bins=20)
plt.xlabel('non_outlier histogram')
wage_data1=non_outlier_count['prevailing_wage']
plt.subplot(2,2,4).boxplot(wage_data1,vert=False)
plt.xlabel('non_outlier boxplot')
plt.show()

# %%
# fill the outliers of wage data with wage median
# 427 outliers
# 427 should replace with median values 
#  again draw the plots

# %%
wage_data=visa_df['prevailing_wage'].median()
wage_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 wage_data=visa_df['prevailing_wage'].median()
#       2 wage_data
#
# NameError: name 'visa_df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\devis\OneDrive\Documents\data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
wage_data_non_outliers=non_outlier_count['prevailing_wage']
wage_data=visa_df['prevailing_wage']
plt.figure(figsize=(14,8))
plt.hist(wage_data)
plt.hist(wage_data_non_outliers)
plt.show()

# %% [markdown]
# # how to deal outliers
# - method-1:drop the outliers
#    - droping outliers is easy task but not recommended
#    - if you drop the outliers means we are droping the rows
#    - which means we are droping the other column values also
#    - may be some important we might loose from other column values
#    - but in industry if outlier percentage <2% of the total data we can drop
#    - the number of outliers in pwage is 427
#    - the number of total observations are 25480
#    - the percentage is 1.67 which is less than 2%

# %% [markdown]
# - method-2: fill with median value
#
#    - WKT outlier doesnt effect by median
#    - so we fill the outliers with median
#
#
# - method-3: capping or florring
#
#   - instead of fill with median we can fill with certain values
#   - the outliers which are less than lb fill with lb
#   - the outliers which are greater than ub fill with ub value only
#
# - isolation forest
#
#   - ML model is used to find the outliers and anamolies

# %% [markdown]
# # fill with median value

# %%
wage_data=visa_df['prevailing_wage'].median()
wage_data
# Out:
# 70308.20999999999

# %%
wage_data_outliers=outlier_count['prevailing_wage']
wage_data_outliers
# Out:
# 14       220081.73
# 34       225569.73
# 130      247393.01
# 216      269321.68
# 221      219529.62
#            ...
# 25191    280482.51
# 25195    234308.77
# 25468    272715.74
# 25469    273772.47
# 25476    279174.79
# Name: prevailing_wage, Length: 427, dtype: float64

# %% [markdown]
# # np.where
# - in numpy we have a method called 'where'
# - it takes 3 arguments
#   - 1.condition
#   - 2.value if condition is True
#   - 3.value if condition is False
# - it is applicable for only binary means if and else

# %%
list1=[]
for value in wage_data:
    if value<lb or value>ub:
        median=wage_data.median()
        list1.append(median)
    else:
         list1.append(value)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 list1=[]
# ----> 2 for value in wage_data:
#       3     if value<lb or value>ub:
#       4         median=wage_data.median()
#
# TypeError: 'float' object is not iterable

# %%
dict1={'sub':['ds','de','cs'],'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   sub  marks
# 0  ds    100
# 1  de    200
# 2  cs    300

# %%
# replace marks with 1 ,which are greater than 100

# %%
con=df['marks']>100
l=np.where(con,1,df['marks'])
con=df['marks']>100
l=np.where(con,1,df['marks'])
df['marks']=l
df
# Out:
# array([1, 1, 1], dtype=int64)

# %%
wage_data=visa_df['prevailing_wage']
con1=wage_data<lb
con2=wage_data>ub
con=con1|con2
wage_median=wage_data.median()
l=np.where(con,wage_median,wage_data)
l
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
visa_df['prevailing_wage_update']=l

# %%
plt.subplot(1,2,1).boxplot(visa_df['prevailing_wage_update'])
plt.subplot(1,2,2).hist(visa_df['prevailing_wage_update'])
# Out:
# (array([4580., 3368., 3890., 4369., 3507., 2860., 1643.,  706.,  295.,
#          262.]),
#  array([2.13670000e+00, 2.18113840e+04, 4.36206314e+04, 6.54298787e+04,
#         8.72391260e+04, 1.09048373e+05, 1.30857621e+05, 1.52666868e+05,
#         1.74476115e+05, 1.96285363e+05, 2.18094610e+05]),
#  <BarContainer object of 10 artists>)

# %%
# practice
dict1={'sub':['ds','de','cs'],'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   sub  marks
# 0  ds    100
# 1  de    200
# 2  cs    300

# %%
dict1={'sub':['ds','de','cs'],'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
l=[]
for i in df['marks']:
    if i>100:
        l.append(1)
    else:
        l.append(i)
df['marks']=l
df
# Out:
#   sub  marks
# 0  ds    100
# 1  de      1
# 2  cs      1

# %%
dict1={'sub':['ds','de','cs'],'marks':[100,200,300]}
df=pd.DataFrame(dict1)
df
# Out:
#   sub  marks
# 0  ds    100
# 1  de    200
# 2  cs    300

# %%
con=df['marks']>100
l=np.where(con,1,df['marks'])
df['marks']=l
df
# Out:
#   sub  marks
# 0  ds    100
# 1  de      1
# 2  cs      1

# %%
wage_data=visa_df['prevailing_wage']
con1=wage_data<lb
con2=wage_data>ub
con=con1|con2
wage_med=wage_data.median()
l=np.where(con,wage_med,wage_data)
l
# Out:
# array([   592.2029,  83425.65  , 122996.86  , ..., 146298.85  ,
#         86154.77  ,  70876.91  ])

# %%
visa_df['prevailing_wage_update']=l

# %%
plt.subplot(1,2,1).boxplot(visa_df['prevailing_wage_update'])
plt.subplot(1,2,2).hist(visa_df['prevailing_wage_update'])
# Out:
# (array([4580., 3368., 3890., 4369., 3507., 2860., 1643.,  706.,  295.,
#          262.]),
#  array([2.13670000e+00, 2.18113840e+04, 4.36206314e+04, 6.54298787e+04,
#         8.72391260e+04, 1.09048373e+05, 1.30857621e+05, 1.52666868e+05,
#         1.74476115e+05, 1.96285363e+05, 2.18094610e+05]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # bi-varient and multi-varient analysis

# %% [markdown]
# - bi-varient analysis
#
#
# - we already see uni varient analysis
# - we perfomed the categorical column analysis
#   - freq table(value counts)
#   - bar chart
#   - relative freq table(value counts normalized form)
#   - pie chart
#
#
# - we performed the numerical column analysis
#
#
#    - histogram
#     - distibution plots
#    - box plot
#    - outlier analysis
#    - filling the outliers
#
# - now we will do categorical to categorial analysis
# - numerical-numerical analysis
# - categorical- numerical analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\devis\OneDrive\Documents\data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # categorical-categorical column
# - lets consider 2 columns
#   - continent
#   - case status

# %%
visa_df['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df['case_status'].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
# task

# find the certified observations continent wise
# find denied observations continent wise
# step-1:make the first cond contient=='Asia'
# step-2:make 2 nd cond case_status=='certified'
# step-3:make the 3rd con :cond1&con2
# step-4:then retrieve the dataframe and take the count

# %%
con1=visa_df['continent']=='Asia'
con2=visa_df['case_status']=='Certified'
con3=con1&con2
len(visa_df[con3])
# Out:
# 11012

# %%
visa_df['continent'].unique
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
continents=visa_df['continent'].unique()
certified_list,denied_list=[],[]
for i in continents:
    con1=visa_df['continent']==i
    con2=visa_df['case_status']=='Certified'
    con3=visa_df['case_status']=='Denied'
    
    cert_con=con1&con2
    den_con=con1&con3
    
    cert_count=len(visa_df[cert_con])
    den_count=len(visa_df[den_con])
    
    print(f'the number of certified visa from {i} is :{cert_count}')
    print(f'the number of denied visa from {i} is :{den_count}')
    certified_list.append(cert_count)
    denied_list.append(den_count)
# Out:
# the number of certified visa from Asia is :11012
# the number of denied visa from Asia is :5849
# the number of certified visa from Africa is :397
# the number of denied visa from Africa is :154
# the number of certified visa from North America is :2037
# the number of denied visa from North America is :1255
# the number of certified visa from Europe is :2957
# the number of denied visa from Europe is :775
# the number of certified visa from South America is :493
# the number of denied visa from South America is :359
# the number of certified visa from Oceania is :122
# the number of denied visa from Oceania is :70

# %%
continents
certified_list
cols=['continents','certified']
df1=pd.DataFrame(zip(continents,certified_list),columns=cols)
df1
# Out:
#       continents  certified
# 0           Asia      11012
# 1         Africa        397
# 2  North America       2037
# 3         Europe       2957
# 4  South America        493
# 5        Oceania        122

# %%
continents
denied_list
cols=['continents','denied']
df2=pd.DataFrame(zip(continents,denied_list),columns=cols)
df2
# Out:
#       continents  denied
# 0           Asia    5849
# 1         Africa     154
# 2  North America    1255
# 3         Europe     775
# 4  South America     359
# 5        Oceania      70

# %%
cols=['certified','denied']
df3=pd.DataFrame(zip(certified_list,denied_list),index=continents,columns=cols)
df3
# Out:
#                certified  denied
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %% [markdown]
# # cross tab
# - the above dataframe we can make by using a method called **cross tab**
# - it is available in pandas
# - it takes 2 arguments
#   - index
#   - columns
# - in above data frame index column is:continent
# - similarly the data columns is:case_status

# %%
ix=visa_df['continent']
data_col=visa_df['case_status']
dfff=pd.crosstab(ix,data_col)
dfff
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
pd.crosstab(visa_df['continent'],visa_df['case_status'])
# Out:
# case_status    Certified  Denied
# continent
# Africa               397     154
# Asia               11012    5849
# Europe              2957     775
# North America       2037    1255
# Oceania              122      70
# South America        493     359

# %%
dfff.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
dfff.plot(kind='line')
# Out:
# <Axes: xlabel='continent'>

# %%
df3.plot(kind='bar')
# Out:
# <Axes: >

# %%
# multi-varient analysis
- education
- continent
- case_status
- we already know from asia 11k accepted visa
- in that i want to further breakdown based on education
- pd.crosstab
   - first fix your index of any one column outof three columns
   - then keep 2 cols in a list and pass as data column

# %%
ix=visa_df['continent']
data_col=[visa_df['education_of_employee'],visa_df['case_status']]
df55=pd.crosstab(ix,data_col)
df55
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
ix=visa_df['education_of_employee']
data_col=[visa_df['continent'],visa_df['case_status']]
df6=pd.crosstab(ix,data_col)
df6
# Out:
# continent                Africa             Asia           Europe         \
# case_status           Certified Denied Certified Denied Certified Denied
# education_of_employee
# Bachelor's                   81     62      4407   2761      1040    259
# Doctorate                    43     11       780    143       788     58
# High School                  23     43       676   1614       162    328
# Master's                    250     38      5149   1331       967    130
#
# continent             North America          Oceania        South America  \
# case_status               Certified Denied Certified Denied     Certified
# education_of_employee
# Bachelor's                      641    584        38     28           160
# Doctorate                       207     51        19      3            75
# High School                     210    191        19     17            74
# Master's                        979    429        46     22           184
#
# continent
# ...

# %%
df55.plot(kind='bar')
# Out:
# <Axes: xlabel='continent'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r"C:\Users\devis\OneDrive\Documents\data science\data files\Visadataset.csv"
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# # numerical-numerical

# %% [markdown]
# - to understand numerical columns relation we need to plot scatter plots
# - scatter plots gives the relation b/w 2 numerical columns
# - bar_chart,pie_chart,histogram and scatter plots
# - scatter plots under matplotlib package
# - **plt.scatter**

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.scatter(x,y)
plt.plot(x,y)

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x,y)
plt.plot(x,y)

# %%
#read 1 num column
#read 2nd numerical column
#apply scatter plot

# %%
column1=visa_df['prevailing_wage']
column2=visa_df['no_of_employees']
plt.scatter(column1,column2)
plt.plot(column1,column2)

# %%
column1=visa_df['prevailing_wage']
column2=visa_df['yr_of_estab']
plt.scatter(column1,column2)

# %%
plt.plot(column1,column2)

# %%
column1=visa_df['no_of_employees']
column2=visa_df['yr_of_estab']
column3=visa_df['prevailing_wage']
##########################################

plt.figure(figsize=(14,3))
################################
plt.subplot(1,3,1)
plt.xlabel('no_of_employees')
plt.ylabel('yr_of_estab')
plt.scatter(column1,column2)
########################################
plt.subplot(1,3,2)
plt.xlabel('no_of_employees')
plt.ylabel('prevailing_wage')
plt.scatter(column1,column3)
###################################
plt.subplot(1,3,3)
plt.xlabel('yr_of_estab')
plt.ylabel('prevailing_wage')
plt.scatter(column2,column3)

# %% [markdown]
# - implement the covariance function
# - covariance vs correlation
# - covariance will tell about the columns have relation or not
# - covariance will explain about relation status
#     - positive relation
#     - negative relation
#     - no relation
# - correlation tells about how much relation b/w two variables
#     - it denotes with 'r'
#     - r varies from **-1 to 1**
#     - -1 to 0 indicates -ve relation
#     - 0 to 1 indicates +ve relation
#     - 0 indicates no relation

# %% [markdown]
# # method name:corr

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
# # heat map
# - heat map is one of the important visualization method,to show the matrix form of values
# - it is under **seaborn** package
# - in every matrix we have highest and lowest values available
# - heat map will give colour visualization
# - also provides color bar,which color indicates which value

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True)
plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True,cmap='Greens')
plt.show()

# %%
corr_data=visa_df.corr(numeric_only=True)
sns.heatmap(corr_data,annot=True,cmap='plasma')
plt.show()

# %% [markdown]
# - by seeing the graphs we might not say the replation status
# - it is best practice to get the percentage of relation using correlation
# - all 3 cols having approximately zero percentage of relation
# - which indicates all the cols having no relation
# - no relation means independent to each other
# - in ML we except the input columns should be independent each other
# - corr method gives matrix view
# - we have 3 columns 3*3 total 9 fields
# - if a data has 20 columns then 20*20 total 400 fields
# - thats why always go with heat map visualization
